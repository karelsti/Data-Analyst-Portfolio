# %% [markdown]
# **Association Rule Mining**
#
# The goal of this analysis is to find interesting relationships between products purchased in a store. By identifying strong associations between products, we can uncover patterns that can help make informed decisions about product promotions and recommendations.

# %%
# Import necessary libraries
import pandas as pd
# Load the dataset from github
url = 'https://raw.githubusercontent.com/karelsti/Data-Analyst-Portfolio/main/python_datamining/association_rule/store.csv'
df = pd.read_csv(url, encoding='latin1')
print(df.head())
# Out:
#    Row.ID         Order.ID  Order.Date   Ship.Date  Ship.Mode Customer.ID  \
# 0   42433     AG-2011-2040  01/01/2011  06/01/2011          4    TB-11280
# 1   22253    IN-2011-47883  01/01/2011  08/01/2011          4    JH-15985
# 2   48883     HU-2011-1220  01/01/2011  05/01/2011          3      AT-735
# 3   11731  IT-2011-3647632  01/01/2011  05/01/2011          3    EM-14140
# 4   22255    IN-2011-47883  01/01/2011  08/01/2011          4    JH-15985
#
#      Customer.Name  Segment         City            State  ... Category  \
# 0  Toby Braunhardt        1  Constantine      Constantine  ...        2
# 1      Joseph Holt        1  Wagga Wagga  New South Wales  ...        2
# 2    Annie Thurman        1     Budapest         Budapest  ...        2
# 3     Eugene Moren        3    Stockholm        Stockholm  ...        2
# 4      Joseph Holt        1  Wagga Wagga  New South Wales  ...        1
#
#    Sub.Category                 Product.Name    Sales Quantity  Discount  \
# 0       Storage          Tenex Lockers, Blue  408.300        2       0.0
# 1      Supplies     Acme Trimmer, High Speed  120.366        3       0.1
# 2       Storage      Tenex Box, Single Width   66.120        4       0.0
# 3         Paper  Enermax Note Cards, Premium   44.865        3       0.5
# 4   Furnishings   Eldon Light Bulb, Duo Pack  113.670        5       0.1
#
#     Profit Shipping.Cost  Status  Order.Priority
# 0  106.140         35.46       1               4
# 1   36.036          9.72       1               4
# 2   29.640          8.17       1               2
# 3  -26.055          4.82       1               2
# 4   37.770          4.70       1               4
#
# [5 rows x 25 columns]

# %%
# Checking the structure of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row.ID          51290 non-null  int64
#  1   Order.ID        51290 non-null  object
#  2   Order.Date      51290 non-null  object
#  3   Ship.Date       51290 non-null  object
#  4   Ship.Mode       51290 non-null  int64
#  5   Customer.ID     51290 non-null  object
#  6   Customer.Name   51290 non-null  object
#  7   Segment         51290 non-null  int64
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal.Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product.ID      51290 non-null  object
#  15  Category        51290 non-null  int64
#  16  Sub.Category    51290 non-null  object
#  17  Product.Name    51290 non-null  object
#  18  Sales           51290 non-null  float64
#  19  Quantity        51290 non-null  int64
#  20  Discount        51290 non-null  float64
#  21  Profit          51290 non-null  float64
#  22  Shipping.Cost   51290 non-null  float64
#  23  Status          51290 non-null  int64
#  24  Order.Priority  51290 non-null  int64
# dtypes: float64(5), int64(7), object(13)
# memory usage: 9.8+ MB

# %%
# Summary Statistics to help identify any outliers
df.describe()
# Out:
#             Row.ID     Ship.Mode       Segment   Postal.Code      Category  \
# count  51290.00000  51290.000000  51290.000000   9994.000000  51290.000000
# mean   25645.50000      3.254709      1.665139  55190.379428      2.005167
# std    14806.29199      1.083110      0.766199  32063.693350      0.624701
# min        1.00000      1.000000      1.000000   1040.000000      1.000000
# 25%    12823.25000      3.000000      1.000000  23223.000000      2.000000
# 50%    25645.50000      4.000000      1.000000  56430.500000      2.000000
# 75%    38467.75000      4.000000      2.000000  90008.000000      2.000000
# max    51290.00000      4.000000      3.000000  99301.000000      3.000000
#
#               Sales      Quantity      Discount        Profit  Shipping.Cost  \
# count  51290.000000  51290.000000  51290.000000  51290.000000   51290.000000
# mean     246.490581      3.476545      0.142908     28.610983      26.375915
# std      487.565362      2.278766      0.212280    174.340972      57.296804
# min        0.444000      1.000000      0.000000  -6599.978000       0.000000
# 25%       30.758625      2.000000      0.000000      0.000000       2.610000
# 50%       85.053000      3.000000      0.000000      9.240000       7.790000
# 75%      251.053200      5.000000      0.200000     36.810000      24.450000
# max    22638.480000     14.000000      0.850000   8399.976000     933.570000
#
#         Status  Order.Priority
# count  51290.0    51290.000000
# mean       1.0        3.118308
# std        0.0        1.081088
# min        1.0        1.000000
# 25%        1.0        2.000000
# 50%        1.0        4.000000
# 75%        1.0        4.000000
# max        1.0        4.000000

# %%
(df['Profit'] < 0).sum()
# The result indicates that negative profit from an order occurs 12,544 times
# Out:
# 12544

# %%
# Let's investigate if there are any missing values in each column
df.isna().sum()
# The 'Postal.Code' column has missing values, but since it's not relevant to our analysis, we'll ignore them
# Out:
# Row.ID                0
# Order.ID              0
# Order.Date            0
# Ship.Date             0
# Ship.Mode             0
# Customer.ID           0
# Customer.Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal.Code       41296
# Market                0
# Region                0
# Product.ID            0
# Category              0
# Sub.Category          0
# Product.Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping.Cost         0
# Status                0
# Order.Priority        0
# dtype: int64

# %%
# I will now check the number of unuqie orders
unique_orders = df['Order.ID'].nunique()
print('Unique Orders:',unique_orders)
unique_products = df['Product.ID'].nunique()
print('Unique Products:',unique_products)
cnt_products = df['Product.ID'].count()
print(f'There are approximately',round(cnt_products/unique_orders),'products per one order')
# we can see that one order will have two items on average
# Out:
# Unique Orders: 25035
# Unique Products: 10292
# There are approximately 2 products per one order

# %%
df['Row.ID'].nunique()
# The number of unique RowIDs is equivalent to the total number of rows, hence we don't have any duplicated rows.
# Out:
# 51290

# %% [markdown]
# **Most popular products**
#
# Displaying most purchased products.

# %%
df['Product.Name'].value_counts().head(10)
# Out:
# Product.Name
# Staples                                  227
# Cardinal Index Tab, Clear                 92
# Eldon File Cart, Single Width             90
# Rogers File Cart, Single Width            84
# Ibico Index Tab, Clear                    83
# Sanford Pencil Sharpener, Water Color     80
# Smead File Cart, Single Width             77
# Stanley Pencil Sharpener, Water Color     75
# Acco Index Tab, Clear                     75
# Avery Index Tab, Clear                    74
# Name: count, dtype: int64

# %% [markdown]
# **Frequent Customers**
#
# Displaying customers with the most amount of orders.

# %%
top_customers = df.groupby(['Customer.ID', 'Customer.Name'])['Product.Name'].count()
top_customers.sort_values(ascending=False).head(10)
# Out:
# Customer.ID  Customer.Name
# PO-18850     Patrick O'Brill        97
# BE-11335     Bill Eplett            94
# JG-15805     John Grady             90
# SW-20755     Steven Ward            89
# EM-13960     Eric Murdock           85
# MY-18295     Muhammed Yedwab        85
# ZC-21910     Zuschuss Carroll       84
# MP-17965     Michael Paige          84
# CK-12205     Chloris Kastensmidt    83
# AF-10870     Art Ferguson           81
# Name: Product.Name, dtype: int64

# %% [markdown]
# **FP-growth vs Apriori Algorithm**
#
# I have decided to use the FP growth algorithm because the Apriori algorithm works by iteratively generating candidate itemsets and counting their support which requires a lot of computational power and memory. FP-growth on the other hand uses FP-tree data structure and eliminates candidate generation and support counting.

# %%
pip install mlxtend
# Installing the mlxtend package
# Out:
# Requirement already satisfied: mlxtend in c:\users\karel\anaconda3\lib\site-packages (0.23.1)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\karel\anaconda3\lib\site-packages (from mlxtend) (1.11.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\karel\anaconda3\lib\site-packages (from mlxtend) (1.24.3)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\karel\anaconda3\lib\site-packages (from mlxtend) (2.0.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\karel\anaconda3\lib\site-packages (from mlxtend) (1.3.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\karel\anaconda3\lib\site-packages (from mlxtend) (3.7.2)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\karel\anaconda3\lib\site-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\karel\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\karel\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\karel\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\karel\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\karel\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\karel\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\karel\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\karel\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\karel\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\karel\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\karel\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\karel\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Transactional Data**
#
# The following code converts categorical product names into binary columns (1 or 0), representing whether a product was part of an order or not. This format is required for association rule mining.

# %%
transaction_data_name = df[['Order.ID','Product.Name']]
transaction_data_name = pd.get_dummies(transaction_data_name['Product.Name']).groupby(transaction_data_name['Order.ID']).max()
transaction_data_name
# Out:
#               "While you Were Out" Message Book, One Form per Page  \
# Order.ID
# AE-2011-9160                                              False
# AE-2013-1130                                              False
# AE-2013-1530                                              False
# AE-2014-2840                                              False
# AE-2014-3830                                              False
# ...                                                         ...
# ZI-2014-7160                                              False
# ZI-2014-7610                                              False
# ZI-2014-9540                                              False
# ZI-2014-9550                                              False
# ZI-2014-9650                                              False
#
#               #10 Gummed Flap White Envelopes, 100/Box  \
# Order.ID
# AE-2011-9160                                     False
# AE-2013-1130                                     False
# AE-2013-1530                                     False
# AE-2014-2840                                     False
# AE-2014-3830                                     False
# ...                                                ...
# ZI-2014-7160                                     False
# ZI-2014-7610                                     False
# ZI-2014-9540                                     False
# ZI-2014-9550                                     False
# ZI-2014-9650                                     False
#
#               #10 Self-Seal White Envelopes  \
# Order.ID
# AE-2011-9160                          False
# AE-2013-1130                          False
# AE-2013-1530                          False
# AE-2014-2840                          False
# AE-2014-3830                          False
# ...                                     ...
# ZI-2014-7160                          False
# ZI-2014-7610                          False
# ZI-2014-9540                          False
# ZI-2014-9550                          False
# ZI-2014-9650                          False
#
#               #10 White Business Envelopes,4 1/8 x 9 1/2  \
# Order.ID
# AE-2011-9160                                       False
# AE-2013-1130                                       False
# AE-2013-1530                                       False
# AE-2014-2840                                       False
# AE-2014-3830                                       False
# ...                                                  ...
# ZI-2014-7160                                       False
# ZI-2014-7610                                       False
# ZI-2014-9540                                       False
# ZI-2014-9550                                       False
# ZI-2014-9650                                       False
#
#               #10- 4 1/8" x 9 1/2" Recycled Envelopes  \
# Order.ID
# AE-2011-9160                                    False
# AE-2013-1130                                    False
# AE-2013-1530                                    False
# AE-2014-2840                                    False
# AE-2014-3830                                    False
# ...                                               ...
# ZI-2014-7160                                    False
# ZI-2014-7610                                    False
# ZI-2014-9540                                    False
# ZI-2014-9550                                    False
# ZI-2014-9650                                    False
#
#               #10- 4 1/8" x 9 1/2" Security-Tint Envelopes  \
# Order.ID
# AE-2011-9160                                         False
# AE-2013-1130                                         False
# AE-2013-1530                                         False
# AE-2014-2840                                         False
# AE-2014-3830                                         False
# ...                                                    ...
# ZI-2014-7160                                         False
# ZI-2014-7610                                         False
# ZI-2014-9540                                         False
# ZI-2014-9550                                         False
# ZI-2014-9650                                         False
#
#               #10-4 1/8" x 9 1/2" Premium Diagonal Seam Envelopes  \
# Order.ID
# AE-2011-9160                                              False
# AE-2013-1130                                              False
# AE-2013-1530                                              False
# AE-2014-2840                                              False
# AE-2014-3830                                              False
# ...                                                         ...
# ZI-2014-7160                                              False
# ZI-2014-7610                                              False
# ZI-2014-9540                                              False
# ZI-2014-9550                                              False
# ZI-2014-9650                                              False
#
#               #6 3/4 Gummed Flap White Envelopes  \
# Order.ID
# AE-2011-9160                               False
# AE-2013-1130                               False
# AE-2013-1530                               False
# AE-2014-2840                               False
# AE-2014-3830                               False
# ...                                          ...
# ZI-2014-7160                               False
# ZI-2014-7610                               False
# ZI-2014-9540                               False
# ZI-2014-9550                               False
# ZI-2014-9650                               False
#
#               1.7 Cubic Foot Compact "Cube" Office Refrigerators  \
# Order.ID
# AE-2011-9160                                              False
# AE-2013-1130                                              False
# AE-2013-1530                                              False
# AE-2014-2840                                              False
# AE-2014-3830                                              False
# ...                                                         ...
# ZI-2014-7160                                              False
# ZI-2014-7610                                              False
# ZI-2014-9540                                              False
# ZI-2014-9550                                              False
# ZI-2014-9650                                              False
#
#               1/4 Fold Party Design Invitations & White Envelopes, 24 8-1/2" X 11" Cards, 25 Env./Pack  \
# Order.ID
# AE-2011-9160                                              False
# AE-2013-1130                                              False
# AE-2013-1530                                              False
# AE-2014-2840                                              False
# AE-2014-3830                                              False
# ...                                                         ...
# ZI-2014-7160                                              False
# ZI-2014-7610                                              False
# ZI-2014-9540                                              False
# ZI-2014-9550                                              False
# ZI-2014-9650                                              False
#
#               ...  Zebra ZM400 Thermal Label Printer  \
# Order.ID      ...
# AE-2011-9160  ...                              False
# AE-2013-1130  ...                              False
# AE-2013-1530  ...                              False
# AE-2014-2840  ...                              False
# AE-2014-3830  ...                              False
# ...           ...                                ...
# ZI-2014-7160  ...                              False
# ZI-2014-7610  ...                              False
# ZI-2014-9540  ...                              False
# ZI-2014-9550  ...                              False
# ZI-2014-9650  ...                              False
#
#               Zebra Zazzle Fluorescent Highlighters  \
# Order.ID
# AE-2011-9160                                  False
# AE-2013-1130                                  False
# AE-2013-1530                                  False
# AE-2014-2840                                  False
# AE-2014-3830                                  False
# ...                                             ...
# ZI-2014-7160                                  False
# ZI-2014-7610                                  False
# ZI-2014-9540                                  False
# ZI-2014-9550                                  False
# ZI-2014-9650                                  False
#
#               Zipper Ring Binder Pockets  i.Sound Portable Power - 8000 mAh  \
# Order.ID
# AE-2011-9160                       False                              False
# AE-2013-1130                       False                              False
# AE-2013-1530                       False                              False
# AE-2014-2840                       False                              False
# AE-2014-3830                       False                              False
# ...                                  ...                                ...
# ZI-2014-7160                       False                              False
# ZI-2014-7610                       False                              False
# ZI-2014-9540                       False                              False
# ZI-2014-9550                       False                              False
# ZI-2014-9650                       False                              False
#
#               iHome FM Clock Radio with Lightning Dock  \
# Order.ID
# AE-2011-9160                                     False
# AE-2013-1130                                     False
# AE-2013-1530                                     False
# AE-2014-2840                                     False
# AE-2014-3830                                     False
# ...                                                ...
# ZI-2014-7160                                     False
# ZI-2014-7610                                     False
# ZI-2014-9540                                     False
# ZI-2014-9550                                     False
# ZI-2014-9650                                     False
#
#               iKross Bluetooth Portable Keyboard + Cell Phone Stand Holder + Brush for Apple iPhone 5S 5C 5, 4S 4  \
# Order.ID
# AE-2011-9160                                              False
# AE-2013-1130                                              False
# AE-2013-1530                                              False
# AE-2014-2840                                              False
# AE-2014-3830                                              False
# ...                                                         ...
# ZI-2014-7160                                              False
# ZI-2014-7610                                              False
# ZI-2014-9540                                              False
# ZI-2014-9550                                              False
# ZI-2014-9650                                              False
#
#               iOttie HLCRIO102 Car Mount  iOttie XL Car Mount  \
# Order.ID
# AE-2011-9160                       False                False
# AE-2013-1130                       False                False
# AE-2013-1530                       False                False
# AE-2014-2840                       False                False
# AE-2014-3830                       False                False
# ...                                  ...                  ...
# ZI-2014-7160                       False                False
# ZI-2014-7610                       False                False
# ZI-2014-9540                       False                False
# ZI-2014-9550                       False                False
# ZI-2014-9650                       False                False
#
#               invisibleSHIELD by ZAGG Smudge-Free Screen Protector  \
# Order.ID
# AE-2011-9160                                              False
# AE-2013-1130                                              False
# AE-2013-1530                                              False
# AE-2014-2840                                              False
# AE-2014-3830                                              False
# ...                                                         ...
# ZI-2014-7160                                              False
# ZI-2014-7610                                              False
# ZI-2014-9540                                              False
# ZI-2014-9550                                              False
# ZI-2014-9650                                              False
#
#               netTALK DUO VoIP Telephone Service
# Order.ID
# AE-2011-9160                               False
# AE-2013-1130                               False
# AE-2013-1530                               False
# AE-2014-2840                               False
# AE-2014-3830                               False
# ...                                          ...
# ZI-2014-7160                               False
# ZI-2014-7610                               False
# ZI-2014-9540                               False
# ZI-2014-9550                               False
# ZI-2014-9650                               False
#
# [25035 rows x 3788 columns]

# %% [markdown]
# **Frequent Itemsets**
#
# The FP-Growth algorithm identifies frequent itemsets with a minimum support threshold of 0.0001.
# Support measures how frequently items occur together in one order.

# %%
from mlxtend.frequent_patterns import fpgrowth
frequent_itemsets_name=fpgrowth(transaction_data_name, min_support=0.0001, use_colnames=True)
frequent_itemsets_name
# Out:
#        support                                           itemsets
# 0     0.001278                   (Fellowes File Cart, Industrial)
# 1     0.000519                            (Epson Calculator, Red)
# 2     0.001758                    (Bush Stackable Bookrack, Pine)
# 3     0.000599                     (Accos Paper Clips, Bulk Pack)
# 4     0.001198                              (Tenex Folders, Blue)
# ...        ...                                                ...
# 3542  0.000120  (Enermax Numeric Keypad, Bluetooth, SanDisk Me...
# 3543  0.000120  (Stockwell Thumb Tacks, Metal, Wilson Jones Bi...
# 3544  0.000120  (Boston Canvas, Easy-Erase, Office Star Rockin...
# 3545  0.000120  (Rogers File Cart, Single Width, Elite Ruler, ...
# 3546  0.000120  (Jiffy Mailers, Set of 50, Memorex Flash Drive...
#
# [3547 rows x 2 columns]

# %% [markdown]
# **Resulting association rules**
#
# The following association rules have a confidence greater than 0.5, meaning that if the antecedent is purchased, there is at least a 50% chance that the consequent will also be bought in the same order. The output displays the strongest association rules.

# %%
from mlxtend.frequent_patterns import association_rules
rules_name = association_rules(frequent_itemsets_name, metric="confidence", min_threshold=0.5)
rules_name
# Out:
#                                         antecedents consequents  \
# 0                        (Hon Olson Stacker Chairs)   (Staples)
# 1  (Hoover Shoulder Vac Commercial Portable Vacuum)   (Staples)
#
#    antecedent support  consequent support  support  confidence       lift  \
# 0             0.00016            0.008868  0.00012        0.75  84.577703
# 1             0.00024            0.008868  0.00012        0.50  56.385135
#
#    leverage  conviction  zhangs_metric
# 0  0.000118    3.964530       0.988334
# 1  0.000118    1.982265       0.982500
